# %%
pip install bokeh
# Out:
# Collecting bokeh
#   Downloading bokeh-3.5.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: Jinja2>=2.9 in /opt/conda/lib/python3.11/site-packages (from bokeh) (3.1.3)
# Requirement already satisfied: contourpy>=1.2 in /opt/conda/lib/python3.11/site-packages (from bokeh) (1.2.1)
# Requirement already satisfied: numpy>=1.16 in /opt/conda/lib/python3.11/site-packages (from bokeh) (2.0.1)
# Requirement already satisfied: packaging>=16.8 in /opt/conda/lib/python3.11/site-packages (from bokeh) (24.0)
# Requirement already satisfied: pandas>=1.2 in /opt/conda/lib/python3.11/site-packages (from bokeh) (2.2.2)
# Requirement already satisfied: pillow>=7.1.0 in /opt/conda/lib/python3.11/site-packages (from bokeh) (10.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /opt/conda/lib/python3.11/site-packages (from bokeh) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in /opt/conda/lib/python3.11/site-packages (from bokeh) (6.4)
# Collecting xyzservices>=2021.09.1 (from bokeh)
#   Downloading xyzservices-2024.6.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from Jinja2>=2.9->bokeh) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.2->bokeh) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.2->bokeh) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.2->bokeh) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh) (1.16.0)
# Downloading bokeh-3.5.0-py3-none-any.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 75.4 MB/s eta 0:00:00:00:0100:01
# Downloading xyzservices-2024.6.0-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 8.3 MB/s eta 0:00:00
# Installing collected packages: xyzservices, bokeh
# Successfully installed bokeh-3.5.0 xyzservices-2024.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.53.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 17.1 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (24.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 106.3 MB/s eta 0:00:0000:0100:01
# Downloading contourpy-1.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (306 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.0/306.0 kB 35.1 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 113.1 MB/s eta 0:00:0000:01
# Downloading kiwisolver-1.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 73.4 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 97.8 MB/s eta 0:00:00:00:01
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 13.9 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.1 kiwisolver-1.4.5 matplotlib-3.9.1 pillow-10.4.0 pyparsing-3.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data (replace with your data source)
stock_data = {
    "Ticker": ["TSLA", "AAPL", "GOOG", "MSFT"],
    "Company Name": ["Tesla Inc.", "Apple Inc.", "Alphabet Inc.", "Microsoft Corporation"],
    "Close Price": [1000, 170, 2500, 300],
    "YoY Growth": [20, 15, 30, 10]
}

# Convert data to DataFrame
data = pd.DataFrame(stock_data)

# Define colors for plots
colors = ["blue", "red"]  # Adjust for more data points

# Stock price and YoY growth subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Stock price plot
ax1.bar(data["Ticker"], data["Close Price"], color=colors[0])
ax1.set_xlabel("Ticker Symbol")
ax1.set_ylabel("Closing Price (USD)")
ax1.set_title("Stock Closing Price")
# Set tick positions and labels with rotation
ax1.set_xticks(data["Ticker"], labels=data["Ticker"], rotation=45)
ax1.grid(True)

# YoY growth plot
ax2.bar(data["Ticker"], data["YoY Growth"], color=colors[1])
ax2.set_xlabel("Ticker Symbol")
ax2.set_ylabel("YoY Growth (%)")
ax2.set_title("YoY Growth")
# Set tick positions and labels with rotation (using plt.xticks)
plt.xticks(data["Ticker"], rotation=45)
ax2.grid(True)

# Title for the entire dashboard
plt.suptitle("Tesla Stock and Revenue Dashboard (Sample Data)")
plt.tight_layout()

# Save the dashboard as an image
plt.savefig("tesla_stock_revenue_dashboard.png")
plt.close()

# Display the dashboard image (optional, requires additional libraries)
# You might need functionalities from libraries like IPython or web frameworks
# to display the image within your environment.

print("Tesla Stock and Revenue Dashboard saved as tesla_stock_revenue_dashboard.png")
# Out:
# Tesla Stock and Revenue Dashboard saved as tesla_stock_revenue_dashboard.png

# %%
from IPython.display import Image

# Assuming the image is saved as "tesla_stock_revenue_dashboard.png"
display(Image(filename="tesla_stock_revenue_dashboard.png"))

# %% [markdown]
# Question 5 - Tesla Stock and Revenue Dashboard - 2 Points
